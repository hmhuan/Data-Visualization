# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('./coronadata/18-5.csv')

# %%
"""
Hàm fmt chuyển định dạng US sang quy ước số
"""
def fmt(x):
    if x == np.nan:
        return np.nan
    if type(x) == float:
        return x
    if type(x) != str:
        x = x.to_string()
    x = x.replace(',','')
    return float(x)

# %%
data['Total Recovered'] = data['Total Recovered'].apply(fmt)
data['Active Cases'] = data['Active Cases'].apply(fmt)

# %%
data_by_country = data[data['#'].isna() == False]
data_non_country = data[data['#'].isna()].reset_index()

# %%
data_non_country.to_csv('./output/regions_1805.csv')

# %%
data_by_country.to_csv('./output/countries_1805.csv')

# %% [markdown]
# # Countries

# %% [markdown]
# ## Top 10 Total cases by Country On 05-18-2020

# %%
Ten_Biggest = data_by_country[:10]

# %% [markdown]
# ### matplotlib

# %%
plt.figure(figsize=(12, 7))
x = [(Ten_Biggest['Country, Other'][i] +'\n(' + str(Ten_Biggest['Total Cases'][i])+')') for i in Ten_Biggest.index]
y = Ten_Biggest['Total Cases']
plt.bar(x, y)
plt.xlabel("Country")
plt.ylabel("Total cases")
plt.title("Top 10 Total cases by Country\n(05-18-2020)")
for i, v in enumerate(Ten_Biggest.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
# plt.savefig('./output/Top_10_TTCases_by_Country_plt.png')
plt.show()

# %% [markdown]
# ### seaborn

# %%
plt.figure(figsize=(12,7))
x = [(Ten_Biggest['Country, Other'][i] 
      + '\n(' + str(Ten_Biggest['Total Cases'][i]) 
      + ')') for i in Ten_Biggest.index]
y = Ten_Biggest['Total Cases']
g = sns.barplot(x='Country, Other', y='Total Cases', data={'Country, Other': x, 'Total Cases': y})
plt.xlabel("Country")
plt.ylabel("Total cases")
plt.title("Top 10 Total cases by Region\n(05-18-2020)")
for i, v in enumerate(Ten_Biggest.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
# plt.savefig('./output/Top_10_TTCase_by_Country_SNS.png')
plt.show()

# %% [markdown]
# # Regions

# %%
six_regions = data_non_country[1:7]

# %% [markdown]
# ## Total cases

# %% [markdown]
# ### matplotlib

# %%
plt.figure(figsize=(10, 7))
x = [(six_regions['Country, Other'][i] +'\n('+ str(six_regions['Total Cases'][i]) +')') for i in six_regions.index]
y = six_regions['Total Cases']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("Total cases")
plt.title("Total cases 6 Regions\n(05-18-2020)")
# plt.savefig('./output/TTCases_Regions_plt.png')
plt.show()

# %% [markdown]
# ### seaborn

# %%
plt.figure(figsize=(10, 7))
x_ = [(six_regions['Country, Other'][i] +'\n('+ str(six_regions['Total Cases'][i]) +')') for i in six_regions.index]
y_ = six_regions['Total Cases']
sns.barplot(x='Country, Other', y='Total Cases', data={'Country, Other': x_, 'Total Cases': y_})
plt.xlabel("Region")
plt.ylabel("Total cases")
plt.title("Total cases 6 Regions\n(05-18-2020)")
# plt.savefig('./output/TTCases_Regions_SNS.png')
plt.show()

# %% [markdown]
# ## Total Deaths

# %% [markdown]
# ### matplotlib

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['Total Deaths']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("Total deaths")
plt.title("Total deaths 6 Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + 2000, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/TTDeaths_Regions_plt.png')
plt.show()

# %% [markdown]
# ### nhận xét
# * Ta thấy châu Âu hiện là khu vực có tổng số ca nhiễm bệnh cao nhất trên thế giới 16319 ca (mặc dù Mỹ đang là nước có số ca nhiễm cao nhất), nhìn chung đa số quốc gia trong khu vực châu Âu (nhất là khối liên minh EU) đều có số ca nhiễm cao.
# * Châu Úc hiện là nơi có số ca nhiễm thấp nhất trong các khu vực với 120 ca.

# %% [markdown]
# ### seaborn

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['Total Deaths']
sns.barplot(x, y)
plt.xlabel("Region")
plt.ylabel("Total deaths")
plt.title("Total deaths 6 Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + 2000, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/TTDeaths_Regions_SNS.png')
plt.show()

# %% [markdown]
# ## New Cases

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['New Cases']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("New cases")
plt.title("New cases 6 Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/NewCases_Regions_plt.png')
plt.show()

# %% [markdown]
# ### nhận xét

# %% [markdown]
# ## New Deaths

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['New Deaths']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("New death")
plt.title("New deaths 6 Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/NewDeaths_Regions_plt.png')
plt.show()

# %% [markdown]
# ### nhận xét

# %% [markdown]
# ## Total Recovered

# %%
six_regions[['Country, Other','Total Recovered']]
# Out:
#   Country, Other  Total Recovered
# 1         Europe         781602.0
# 2  North America         445705.0
# 3           Asia         471876.0
# 4  South America         162622.0
# 5         Africa          34879.0
# 6        Oceania           7926.0

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['Total Recovered']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("Total Recovered")
plt.title("Total Recovered by Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/TotalRecovered_Regions_plt.png')
plt.show()

# %% [markdown]
# ## Active cases

# %%
six_regions[['Country, Other','Active Cases']]
# Out:
#   Country, Other  Active Cases
# 1         Europe      852307.0
# 2  North America     1161159.0
# 3           Asia      321948.0
# 4  South America      274460.0
# 5         Africa       52352.0
# 6        Oceania         617.0

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['Active Cases']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("Active Cases")
plt.title("Active Cases by Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/ActiveCases_Regions_plt.png')
plt.show()

# %% [markdown]
# ## Serious, Critical

# %%
plt.figure(figsize=(12, 8))
x = six_regions['Country, Other']
y = six_regions['Serious, Critical']
plt.bar(x, y)
plt.xlabel("Region")
plt.ylabel("Serious, Critical")
plt.title("Serious, Critical by Regions\n(05-18-2020)")
for i, v in enumerate(six_regions.index):
    plt.text(x = i , y = y[v] + y[v]/100, s = str(y[v]), size = 12, ha='center')
plt.savefig('./output/Serious-Critical_Regions_plt.png')
plt.show()

# %% [markdown]
# ## Multiple

# %%
six_regions
# Out:
#    index   # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 1      1 NaN         Europe      1797528    16760.0      163619.0       780.0
# 2      2 NaN  North America      1711000    26742.0      104136.0      1217.0
# 3      4 NaN           Asia       818935    20627.0       25111.0       377.0
# 4      5 NaN  South America       461197    21015.0       24115.0       998.0
# 5     17 NaN         Africa        90080     3699.0        2849.0        72.0
# 6     53 NaN        Oceania         8663       15.0         120.0         1.0
#
#   Total Recovered Active Cases  Serious, Critical  Tot Cases/ 1M pop  \
# 1         781,602      852,307            11376.0                NaN
# 2         445,705    1,161,159            18026.0                NaN
# 3         471,876      321,948             4583.0                NaN
# 4         162,622      274,460            10478.0                NaN
# 5          34,879       52,352              285.0                NaN
# 6           7,926          617               12.0                NaN
#
#    Deaths/ 1M pop  Total Tests  Tests/ \r\n1M pop  Population
# 1             NaN          NaN                NaN         NaN
# 2             NaN          NaN                NaN         NaN
# 3             NaN          NaN                NaN         NaN
# 4             NaN          NaN                NaN         NaN
# 5             NaN          NaN                NaN         NaN
# 6             NaN          NaN                NaN         NaN

# %%
##
